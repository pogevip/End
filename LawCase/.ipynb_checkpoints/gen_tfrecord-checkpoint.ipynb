# %%
from TextClassifier.TfrecordGenerator import HanTfrecordGenerator, TextCnnTfrecordGenerator

# %%
data_path = 'data/trainSet/train_info.csv'

# %%
htg = HanTfrecordGenerator(data_path)
# Out:
# load data...
# Han start...

# %%
htg.df
# Out:
#                                                rough_token  \
# 0        2015 年 月 日 下午 时 左右 山马 清泉 西街 村 造纸厂 旁边 耕地 转运 驾驶 ...
# 1        2014 年 月 日 时 50 分 臧玉春 驾驶 黑 福田 牌 普通 货车 兰西县 临江镇 ...
# 2        陈天鹏 户口。陈天鹏 孙某 系 星桥 中学 在校。福林 陈天鹏 父亲 汤妙志 孙建文 系 孙...
# 3        年 月 日晚 21 时许 衡阳市 湖南路 邮政 前 夜市 竞争 刘兰英 摊位 廖 发生争执 ...
# 4        年 月 日晚 朱 前进 放炮 时 朱毅超 炸伤。嗣后 朱毅超 之母 陪同 进入 第四军医大学...
# 5        2015 年 正月初三 上午 时 蔡碧珍 张兰荣 发生 语言 冲突 发生 抓扯 张兰荣 夫 ...
# 6        2015 年 28 日 兴隆 汽校 陪 检车 发生争执 厮打 打伤 住院。受伤 后在 兴隆 ...
# 7        房院 位于 赵村 北 位于 该院 东南角 东西向 街道 宽 南房正 一村 南北向 街道 房院...
# 8        明系 商 学文 周 菊芳 姚舜禹 表哥。双方 原材料 问题 纠纷 年 25 日 四 进入 卢...
# 9        2015 年 月 13 日 1000 00 元 丢失 斯琴 去过 家 怀疑 斯琴 派出所 报...
# 10       2013 日 13 06 王 水龙 驾驶 加装 动力装置 人力 三轮车 行驶 嘉兴市 昌盛 ...
# 11       2013 年 月 日 赵福成 科 后旗 甘旗 卡镇 阿克 台嘎查 东南 坨子 处 放牧 11...
# 12       原 系 邻居 关系。2014 年 日 11 姚春 贵在 房西 圈地 准备 放 粪 正碰 摩托...
# 13       2014 年 月 15 日 下午 北大 壕 放羊 期间 家 羊 家 羊 混群 家 一只 羊 ...
# 14       2014 年 月 时许 收摊 巧家县 白鹤 滩 镇平 正街 银行 巷道 里 马义荣 驶进 里...
# ...

# %%
htg.preprocess_data()
# Out:
# /root/notebookPlace/wangxiao/TextClassifier/TfrecordGenerator.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.train_data.dropna(how='any', inplace=True)
# /root/notebookPlace/wangxiao/TextClassifier/TfrecordGenerator.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.val_data.dropna(how='any', inplace=True)
# load finished.
# train/val/test = 1841876/220470/248272
# processing...
# /root/notebookPlace/wangxiao/TextClassifier/TfrecordGenerator.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
htg.train_data.groupby('cls').count()
# Out:
#       rough_token  train_val_test
# cls
# 9001        56267           56267
# 9012       440000          440000
# 9047        72482           72482
# 9130       440000          440000
# 9299        70285           70285
# 9461       111403          111403
# 9483        65171           65171
# 9542        81716           81716
# 9705       440000          440000
# 9771        64552           64552

# %%
htg.out(path='data/trainSet/')

# %%
code2label = {9047: 9, 9299: 6, 9771: 5, 9012: 7, 9461: 8, 9542: 0, 9001: 3, 9705: 1, 9130: 2, 9483: 4}
y = [2,2,3,5,7,4,1,4,2,3,6,1]

arr = [[1,2,3,4],[5,6,7]]

# %%
max(max(arr))
# Out:
# 7

# %%
text_tmp = [['I love you', 'This must be boy', 'This is a a dog'],
          ['This is a cat','hao high ou', 'wo ai bei jing tian an men']]
max_document_length = max(map(lambda doc : len(doc), text_tmp))
max_sentence_length = max(map(lambda doc : max(map(lambda sen : len(sen.split(' ')), doc)), text_tmp))
print(max_document_length, max_sentence_length)
# Out:
# 3 7

# %%
text = '2012 年 11 月 21 日 山东 东营 胜利 农村 合作 银行 贷款人 李 团结 借款人 签订 借款 合同 合同 约定 李 团结 处 借款 75000 元 借款 期限 2012 年 11 月 21 日 起至 2013 年 11 月 19 日 止 借款 用途 贷款 归还 贷款 借款 种类 短期贷款 借款 利率 固定 利率 借款 发放 日所 对应 中国人民银行 人民币 贷款 基准利率 基础 上浮 130 确定 每笔 借款 执行 约定 利率 直至 借款 期内 不变 借款人 利随 本清 方法 偿还 借款 本息 借款人 未 本合同 约定 期限 归还 借款 本金 贷款人 逾期 借款 逾期 之日起 借款 执行 利率 基础 上浮 50 计收 罚息 直至 本息 清偿 应付 未付 利息 贷款人 中国人民银行 规定 计 收复 利。同日 债权人 李 增光 杨 玫瑰 保证 赵 波海 保证 签订 保证 合同 李 增光 杨 玫瑰 赵 波海 债权人 主合同 李 团结 形成 债权 提供 保证 保证 范围 包括 债权 本金 利息 罚息 复利 违约金 损害 赔偿金 实现 债权 费用 包括 限于 诉讼费 律师费 评估费 保证 期间 为主 合同 约定 债务人 履行 债务 期限 届满 之日起 两年。2012 年 11 月 21 日 李 团结 发放 借款 本金 75000 元 约定 借款 利率 11 借款 2013 年 11 月 19 日。借款 期限 届满 李 团结 未 履行 还款 义务 杨 玫瑰 赵 波海 亦 未 履行 保证 义务。2014 年 月 日 李 增光 交通事故 死亡'

# %%
def helper(doc):
    sents = filter(lambda x: len(x.strip())>0, doc.split('。'))
    sents = map(lambda sent: list(filter(lambda x: len(x.strip())>0, sent.split(' '))), sents)
    return list(sents)
