# %%
from TextClassifier import train
# Out:
# Using TensorFlow backend.

# %%
import os

dir = 'data/trainSet/classifier/'

# #一起存储
# data_path = os.path.join(dir, 'train_file_5w')
#按类区分存储
data_path = os.path.join(dir, 'web_train_file_dnn')

class_weight_path = os.path.join(dir, 'web_cls.dic')

# %%
out_path = dir + 'training/web_TextCNN'
train.train(data_path,
            class_weight_path,
            out_path,
            model_option = 'textcnn')
# Out:
# load_data
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# x_seq (InputLayer)              (None, 200)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 200, 256)     20880128    x_seq[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 198, 256)     196864      embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 197, 256)     262400      embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 196, 256)     327936      embedding_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 1, 256)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 1, 256)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 1, 256)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 256)          0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 256)          0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 768)          0           flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 768)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           49216       dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           650         dense_1[0][0]
# ==================================================================================================
# Total params: 21,717,194
# Trainable params: 21,717,194
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# start_train...
# Epoch 1/10
#   74/1312 [>.............................] - ETA: 28:09 - loss: 0.0754 - myacc: 0.6521

# %%
out_path = dir + 'training/web_BiLSTM'
train.train(data_path,
            class_weight_path,
            out_path,
            model_option = 'bilstm')

# %%
out_path = dir + 'training/web_BiLSTM_att'
train.train(data_path,
            class_weight_path,
            out_path,
            model_option = 'bilstm+att')

# %%
from TextClassifier import train_lda
# Out:
# Using TensorFlow backend.

# %%
import os
dir = 'data/trainSet/classifier/'
data_path = os.path.join(dir, 'web_train_file_lda_att')
out_path = dir + 'training/TextCNN_lda_att'
# Out:
# load_data
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# x_seq (InputLayer)           (None, 80)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               10368
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 11,658
# Trainable params: 11,658
# Non-trainable params: 0
# _________________________________________________________________
# None
# start_train...
# Epoch 1/20
# 1312/1312 [==============================] - 166s 127ms/step - loss: 16.6228 - my_metric: 0.7877 - val_loss: 16.6070 - val_my_metric: 0.8239
# Epoch 2/20
# 1312/1312 [==============================] - 166s 126ms/step - loss: 16.6055 - my_metric: 0.8269 - val_loss: 16.6046 - val_my_metric: 0.8327
# Epoch 3/20
# 1312/1312 [==============================] - 165s 126ms/step - loss: 16.6042 - my_metric: 0.8322 - val_loss: 16.6029 - val_my_metric: 0.8375
# Epoch 4/20
# 1312/1312 [==============================] - 165s 126ms/step - loss: 16.6029 - my_metric: 0.8373 - val_loss: 16.6026 - val_my_metric: 0.8390
# Epoch 5/20
# 1312/1312 [==============================] - 166s 126ms/step - loss: 16.6022 - my_metric: 0.8404 - val_loss: 16.6019 - val_my_metric: 0.8426
# Epoch 6/20
# 1312/1312 [==============================] - 165s 126ms/step - loss: 16.6011 - my_metric: 0.8446 - val_loss: 16.6017 - val_my_metric: 0.8421
# Epoch 7/20
# 1312/1312 [==============================] - 166s 126ms/step - loss: 16.6007 - my_metric: 0.8478 - val_loss: 16.6008 - val_my_metric: 0.8475
# Epoch 8/20
# 1312/1312 [==============================] - 166s 127ms/step - loss: 16.6001 - my_metric: 0.8502 - val_loss: 16.6004 - val_my_metric: 0.8505
# Epoch 9/20
# 1312/1312 [==============================] - 166s 127ms/step - loss: 16.5997 - my_metric: 0.8529 - val_loss: 16.6003 - val_my_metric: 0.8487
# Epoch 10/20
# 1312/1312 [==============================] - 166s 126ms/step - loss: 16.5994 - my_metric: 0.8552 - val_loss: 16.5996 - val_my_metric: 0.8523
# Epoch 11/20
# 1312/1312 [==============================] - 165s 126ms/step - loss: 16.5991 - my_metric: 0.8567 - val_loss: 16.5995 - val_my_metric: 0.8520
# Epoch 12/20
# 1312/1312 [==============================] - 166s 126ms/step - loss: 16.5987 - my_metric: 0.8575 - val_loss: 16.5991 - val_my_metric: 0.8553
# Epoch 13/20
# 1312/1312 [==============================] - 166s 126ms/step - loss: 16.5988 - my_metric: 0.8575 - val_loss: 16.5989 - val_my_metric: 0.8566
# Epoch 14/20
# 1312/1312 [==============================] - 166s 126ms/step - loss: 16.5984 - my_metric: 0.8597 - val_loss: 16.5990 - val_my_metric: 0.8545
# Epoch 15/20
# 1312/1312 [==============================] - 167s 127ms/step - loss: 16.5980 - my_metric: 0.8611 - val_loss: 16.5982 - val_my_metric: 0.8577
# Epoch 16/20
#  747/1312 [================>.............] - ETA: 1:03 - loss: 16.5978 - my_metric: 0.8615

# %%
import pandas as pd
import os

df = pd.read_csv('data/trainSet/classifier/training/textcnn_web/log.csv')
df
# Out:
#    epoch       loss    my_acc   val_loss  val_my_acc
# 0      0  16.592410  0.916453  16.588455    0.930996
# 1      1  16.584127  0.958365  16.588213    0.930937
# 2      2  16.582334  0.970566  16.588689    0.933475
# 3      3  16.581271  0.977932  16.589539    0.932939
# 4      4  16.580603  0.982806  16.591292    0.932384
# 5      5  16.580167  0.986164  16.592503    0.932424
# 6      6  16.579903  0.988037  16.595025    0.927903
# 7      7  16.579787  0.989151  16.594546    0.930679
# 8      8  16.579588  0.990821  16.596729    0.929390
# 9      9  16.579487  0.991842  16.596756    0.924988

# %%
import pandas as pd
import os

df = pd.read_csv('data/trainSet/classifier/training/BiLSTM/log.csv')
df

# %%
import pandas as pd
import os

df = pd.read_csv('data/trainSet/classifier/training/BiLSTMAtt/log.csv')
df
# Out:
#    epoch      loss  my_metric  val_loss  val_my_metric
# 0      0  0.011853   0.910716  0.005476       0.945711
# 1      1  0.004556   0.950338  0.005194       0.948311
# 2      2  0.003392   0.958049  0.005228       0.946755
# 3      3  0.002527   0.964910  0.005956       0.946981
# 4      4  0.001811   0.972639  0.006412       0.947028
# 5      5  0.001254   0.979757  0.007727       0.946549
# 6      6  0.000895   0.985113  0.008551       0.945890
# 7      7  0.000653   0.989060  0.010371       0.946010
# 8      8  0.000506   0.991655  0.011363       0.943982
# 9      9  0.000389   0.993573  0.011880       0.946130
