# %%
import pandas as pd
import os

pd.set_option('max_colwidth', 500)

# %%
data_path = 'data/all_info.csv'

# %%
df = pd.read_csv(data_path)

# %%
df

# %%
df.loc[df['id']=='5a31af330e2c810b3c742dd4','cls'][0]
# Out:
# 9130

# %%
import matplotlib.pyplot as plt
tmp = df[df['cls']==9771]
tmp.loc[:,['doc_len_rigour']].plot.box()

plt.grid(linestyle="--", alpha=0.3)
plt.show()

# %%
df_9771 = df[(df['cls']==9771) & (df['doc_len_rigour']<=600) & (df['doc_len_rigour']>=5)]
len(df_9771)
# Out:
# 1688

# %%
df[(df['cls']==9771) & (df['doc_len_rigour'])]
# Out:
# Empty DataFrame
# Columns: [id, text, rough_token, rigour_token, is_fact, statute_code, cls, sent_num_rough, max_sentlen_rough, doc_len_rough, sent_num_rigour, max_sentlen_rigour, doc_len_rigour]
# Index: []

# %%
df_9001 = df[(df['cls']==9001) & (df['doc_len_rigour']<=500) & (df['doc_len_rigour']>=5)]
df_9012 = df[(df['cls']==9012) & (df['doc_len_rigour']<=500) & (df['doc_len_rigour']>=5)]
df_9047 = df[(df['cls']==9047) & (df['doc_len_rigour']<=500) & (df['doc_len_rigour']>=5)]
df_9130 = df[(df['cls']==9130) & (df['doc_len_rigour']<=500) & (df['doc_len_rigour']>=5)]
df_9299 = df[(df['cls']==9299) & (df['doc_len_rigour']<=800) & (df['doc_len_rigour']>=5)]
df_9461 = df[(df['cls']==9461) & (df['doc_len_rigour']<=500) & (df['doc_len_rigour']>=5)]
df_9483 = df[(df['cls']==9483) & (df['doc_len_rigour']<=500) & (df['doc_len_rigour']>=5)]
df_9542 = df[(df['cls']==9542) & (df['doc_len_rigour']<=500) & (df['doc_len_rigour']>=5)]
df_9705 = df[(df['cls']==9705) & (df['doc_len_rigour']<=800) & (df['doc_len_rigour']>=5)]
df_9771 = df[(df['cls']==9771) & (df['doc_len_rigour']<=600) & (df['doc_len_rigour']>=5)]

# %%
df

# %%
df.groupby('cls').count()
# Out:
#            id     text  rough_token  rigour_token  is_fact  statute_code  \
# cls
# 9001    89028    89028        89028         89025    89028         89028
# 9012   750815   750815       750811        750809   750815        750815
# 9047   115028   115028       115028        115026   115028        115028
# 9130  2331551  2331551      2331534       2331504  2331551       2331551
# 9299    32123    32123        32123         32123    32123         32123
# 9461   173933   173933       173930        173920   173933        173933
# 9483     3171     3171         3171          3171     3171          3171
# 9542    66999    66999        66998         66998    66999         66999
# 9705   590498   590498       590491        590467   590498        590498
# 9771     1786     1786         1786          1786     1786          1786
#
#       sent_num_rough  max_sentlen_rough  doc_len_rough  sent_num_rigour  \
# cls
# 9001           89028              89028          89028            89028
# ...

# %%
df[df['statute_code']==9130]

# %%
train_data = pd.read_csv('data/trainSet/train_info.csv')
train_data

# %%
df['rigour_token'].tolist()

# %%
import matplotlib.pyplot as plt

# %%
df.loc[:,['sent_num_rough', 'sent_num_rigour']].plot.box()

plt.grid(linestyle="--", alpha=0.3)
plt.show()

# %%
df.loc[:,['max_sentlen_rough', 'max_sentlen_rigour']].plot.box()

plt.grid(linestyle="--", alpha=0.3)
plt.show()

# %%
df.loc[:, ['doc_len_rough', 'doc_len_rigour']].plot.box()

plt.grid(linestyle="--", alpha=0.3)
plt.show()

# %%
import pandas as pd
data = pd.read_csv('data/data.csv')
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#                                                       text statute_code
# 0                                                      NaN         9181
# 1        2011 年 10 月 13 日 ， 李 某某 向 沈 某某 借款 100000 元 ， 并...         9181
# 2        1997 年 4 月 21 日 ， 原告 将 承包 责任田 0 ． 585 公顷 租赁 给 ...         9258
# 3        原告 系二 被告 村民 ， 户口 落 在 第一 被告 处 。 2009 年 6 月份 ， 被...         9577
# 4        2015 年 6 月 19 日 5 时 ， 在 新阜 线 黑山县 小东镇 铁路 立交桥 西 ...         9722
# 5        2013 年 7 月 26 日 ， 被告 章梅光 因 购车 向 中国农业银行 股份 有限公司...         9293
# 6        原告 在 环县 洪德乡 洪德 街道 经营 蔬菜 、 粮油 门市 ， 2012 年 4 月 至...         9142
# 7        2009 年 4 月 1 日 ， 原告 杨雪梅 与 被告 陈德祥 签订 售车 协议 一份 ，...         9142
# 8        原告 原 为 大石桥市 沟沿 水利 管理处 职工 ， 因 放长假 ， 2014 年 8 月 ...         9710
# 9        恒创 公司 于 2003 年 11 月 18 日 成立 ， 系 有限责任 公司 ， 工商登记...         9164
# 10       2005 年 12 月 19 日 ， 原 、 被告 签订 购销 合同 一份 ， 合同 约定 ...         9142
# 11       原 、 被告 系拟亲 。 2012 年 11 月 24 日 ， 被告 因 需向 原告 借款 ...         9181
# ...
