# %%
from TextClassifier import test
# Out:
# Using TensorFlow backend.

# %%
data_path = 'data/trainSet/classifier/train_file_5w_1'
model_path = 'data/trainSet/classifier/training/BiLSTMAtt'
cls_dic_path = 'data/trainSet/classifier/cls_5w.dic'
out_path = 'data/trainSet/classifier/test'

# %%
# cm, cls = test.test(data_path, model_path, cls_dic_path)
# Out:
# load data
# load model
# predict...
# [1 5 7 ... 0 7 9]

# %%
import numpy as np
from TextClassifier.data_helper import load_cls_dict

import matplotlib.pyplot as plt
import matplotlib.pylab as pylab

plt.rcParams['savefig.dpi'] = 100 #图片像素
plt.rcParams['figure.dpi'] = 100 #分辨率

cls = load_cls_dict(cls_dic_path)
cm = np.load('data/trainSet/classifier/test/TextCNN_cm.npy')

params = {
    'axes.labelsize': '20',
    'xtick.labelsize': '15',
    'ytick.labelsize': '15',
    'lines.linewidth': '1',
    'figure.figsize': '8, 8'  # set figure size
}
pylab.rcParams.update(params)
test.show(cm, cls, 'BiLSTMAtt', out_path)
# Out:
# Confusion matrix, without normalization
# Normalized confusion matrix
